# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("student_daily_data.csv")
df
# Out:
#    Day  Study_Hours  Sleep_Hours
# 0  Mon            2            7
# 1  Tue            3            6
# 2  Wed            4            6
# 3  Thu            3            7
# 4  Fri            5            5
# 5  Sat            6            8
# 6  Sun            4            7

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()

for i in df.columns:
    if df[i].dtypes=='object':
        df[i] = encoder.fit_transform(df[i])

# %%
df
# Out:
#    Day  Study_Hours  Sleep_Hours
# 0    1            2            7
# 1    5            3            6
# 2    6            4            6
# 3    4            3            7
# 4    0            5            5
# 5    2            6            8
# 6    3            4            7

# %%
plt.imshow(df, cmap = 'plasma', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
x=df["Study_Hours"].head()
x
# Out:
# 0    2
# 1    3
# 2    4
# 3    3
# 4    5
# Name: Study_Hours, dtype: int64

# %%
y=df["Sleep_Hours"].head()
y
# Out:
# 0    7
# 1    6
# 2    6
# 3    7
# 4    5
# Name: Sleep_Hours, dtype: int64

# %%
df2=df["Day"].head()
df2
# Out:
# 0    Mon
# 1    Tue
# 2    Wed
# 3    Thu
# 4    Fri
# Name: Day, dtype: object

# %%
df3=df["Day"].head(5)
df3
# Out:
# 0    Mon
# 1    Tue
# 2    Wed
# 3    Thu
# 4    Fri
# Name: Day, dtype: object

# %%
df4=df.head()
df4
# Out:
#    Day  Study_Hours  Sleep_Hours
# 0  Mon            2            7
# 1  Tue            3            6
# 2  Wed            4            6
# 3  Thu            3            7
# 4  Fri            5            5

# %%
df5=df.info()
df5
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          7 non-null      object
#  1   Study_Hours  7 non-null      int64
#  2   Sleep_Hours  7 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 300.0+ bytes

# %%
df6=df.describe()
df6
# Out:
#        Study_Hours  Sleep_Hours
# count     7.000000     7.000000
# mean      3.857143     6.571429
# std       1.345185     0.975900
# min       2.000000     5.000000
# 25%       3.000000     6.000000
# 50%       4.000000     7.000000
# 75%       4.500000     7.000000
# max       6.000000     8.000000

# %%
df7=df.tail()
df7
# Out:
#    Day  Study_Hours  Sleep_Hours
# 2  Wed            4            6
# 3  Thu            3            7
# 4  Fri            5            5
# 5  Sat            6            8
# 6  Sun            4            7

# %%
plt.scatter(x,y, marker = '*', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot of Birth rate of each Country')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.plot(x,y, marker = 'o', color = 'red', label = 'data')
plt.xlabel('Study_ Hours')
plt.ylabel('Sleep_hours')
plt.title('Line plot of student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.bar(x,y, color = "orange", label = 'data')
plt.xlabel('Study_Hours')
plt.ylabel('Sleep_hours')
plt.title('bar Graph of  student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = ',', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = 'o', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = '<', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = '>', color = 'red', label = 'Male')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(False)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = '.', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = 's', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = 'p', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = 'h', color = 'green', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = '+', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = 'x', color = 'yellow', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = 'd', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
plt.scatter(x,y, marker = 'D', color = 'red', label = 'data')
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Scatter plot student activity')
plt.grid(True)
plt.legend()
plt.show()

# %%
data = np.random.randn(5,10)
plt.boxplot(data)
plt.xlabel('Study_Hour')
plt.ylabel('Sleep_Hour')
plt.title('Box plot')
plt.grid(True)
plt.show()

# %%
categories = ['A','B','C','D']
values1 =[20,12,13,42]
values2 = [15,16,20,10]
plt.bar(categories, values1, color = 'green', label = 'data 1')
plt.bar(categories, values2, color = 'orange', bottom = values1, label = 'data')
plt.xlabel('categories')
plt.ylabel('values')
plt.title('Stacked Bar plot')
plt.legend()
plt.show()

# %%
data = [np.random.normal(0, std, 100) for std in range(1, 4)]
plt.violinplot(data, showmedians=True)
plt.xlabel('Distribution')
plt.ylabel('Value')
plt.title('Violin Plot')
plt.xticks(np.arange(1, len(data) + 1), ['Data 1', 'Data 2', 'Data 3'])
plt.legend(['Median'])
plt.show()

# %%
plt.imshow(df, cmap = 'viridis', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'plasma', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'coolwarm', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'inferno', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'bwr', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'Blues', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'Greens', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'Reds', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'jet', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'rainbow', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
plt.imshow(df, cmap = 'magma', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split

# %%
data=pd.read_csv(r"C:\Users\Lenovo\OneDrive\Desktop\cumulative.csv")
data
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE      1.000              0              0              0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 47 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   kepoi_name         9564 non-null   object
#  3   kepler_name        2294 non-null   object
#  4   koi_disposition    9564 non-null   object
#  5   koi_pdisposition   9564 non-null   object
#  6   koi_score          8054 non-null   float64
#  7   koi_fpflag_nt      9564 non-null   int64
#  8   koi_fpflag_ss      9564 non-null   int64
#  9   koi_fpflag_co      9564 non-null   int64
#  10  koi_fpflag_ec      9564 non-null   int64
#  11  koi_period         9564 non-null   float64
#  12  koi_period_err1    9110 non-null   float64
#  13  koi_period_err2    9110 non-null   float64
#  14  koi_time0bk        9564 non-null   float64
#  15  koi_time0bk_err1   9110 non-null   float64
# ...

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

for i in data.columns:
    if data[i].dtypes=='object':
        data[i] = le.fit_transform(data[i])

# %%
data
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0         1  10797460        1080         1035                1
# 1         2  10797460        1081         1036                1
# 2         3  10811496        1082         2294                2
# 3         4  10848459        1083         2294                2
# 4         5  10854555        1084         1867                1
# ...     ...       ...         ...          ...              ...
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# 1                    0      0.969              0              0
# ...

# %%
data.shape
# Out:
# (9564, 47)

# %%
data.head()
# Out:
#    rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0      1  10797460        1080         1035                1
# 1      2  10797460        1081         1036                1
# 2      3  10811496        1082         2294                2
# 3      4  10848459        1083         2294                2
# 4      5  10854555        1084         1867                1
#
#    koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0                 0      1.000              0              0              0
# 1                 0      0.969              0              0              0
# 2                 1      0.000              0              1              0
# 3                 1      0.000              0              1              0
# 4                 0      1.000              0              0              0
#
#    ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
data.tail()
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 9559                 1      0.000              0              0
# 9560                 1      0.000              0              1
# 9561                 0      0.497              0              0
# 9562                 1      0.021              0              0
# 9563                 1      0.000              0              0
#
#       koi_fpflag_co  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 9559              0  ...          -152.0      4.296           0.231
# ...

# %%
data.iloc[0:34]
# Out:
#     rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0       1  10797460        1080         1035                1
# 1       2  10797460        1081         1036                1
# 2       3  10811496        1082         2294                2
# 3       4  10848459        1083         2294                2
# 4       5  10854555        1084         1867                1
# 5       6  10872983        1085         1039                1
# 6       7  10872983        1086         1038                1
# 7       8  10872983        1087         1037                1
# 8       9   6721123         107         2294                2
# 9      10  10910878        1088         1041                1
# 10     11  11446443           0            0                1
# 11     12  10666592           1          953                1
# 12     13   6922244          10         2030                1
# 13     14  10984090         105         1603                1
# ...

# %%
data.loc["kepler_name":"koi_kepmag"]
# Out:
# Empty DataFrame
# Columns: [rowid, kepid, kepoi_name, kepler_name, koi_disposition, koi_pdisposition, koi_score, koi_fpflag_nt, koi_fpflag_ss, koi_fpflag_co, koi_fpflag_ec, koi_period, koi_period_err1, koi_period_err2, koi_time0bk, koi_time0bk_err1, koi_time0bk_err2, koi_impact, koi_impact_err1, koi_impact_err2, koi_duration, koi_duration_err1, koi_duration_err2, koi_depth, koi_depth_err1, koi_depth_err2, koi_prad, koi_prad_err1, koi_prad_err2, koi_teq, koi_insol, koi_insol_err1, koi_insol_err2, koi_model_snr, koi_tce_plnt_num, koi_steff, koi_steff_err1, koi_steff_err2, koi_slogg, koi_slogg_err1, koi_slogg_err2, koi_srad, koi_srad_err1, koi_srad_err2, ra, dec, koi_kepmag]
# Index: []
#
# [0 rows x 47 columns]

# %%
data.describe()
# Out:
#              rowid         kepid   kepoi_name  kepler_name  koi_disposition  \
# count  9564.000000  9.564000e+03  9564.000000  9564.000000      9564.000000
# mean   4782.500000  7.690628e+06  4781.500000  2018.763174         1.290151
# std    2761.033321  2.653459e+06  2761.033321   587.623512         0.822271
# min       1.000000  7.574500e+05     0.000000     0.000000         0.000000
# 25%    2391.750000  5.556034e+06  2390.750000  2294.000000         1.000000
# 50%    4782.500000  7.906892e+06  4781.500000  2294.000000         2.000000
# 75%    7173.250000  9.873066e+06  7172.250000  2294.000000         2.000000
# max    9564.000000  1.293514e+07  9563.000000  2294.000000         2.000000
#
#        koi_pdisposition    koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# count       9564.000000  8054.000000    9564.000000    9564.000000
# mean           0.529904     0.480829       0.188206       0.231598
# std            0.499131     0.476928       0.390897       0.421875
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9564 entries, 0 to 9563
# Data columns (total 47 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   rowid              9564 non-null   int64
#  1   kepid              9564 non-null   int64
#  2   kepoi_name         9564 non-null   int64
#  3   kepler_name        9564 non-null   int64
#  4   koi_disposition    9564 non-null   int64
#  5   koi_pdisposition   9564 non-null   int64
#  6   koi_score          8054 non-null   float64
#  7   koi_fpflag_nt      9564 non-null   int64
#  8   koi_fpflag_ss      9564 non-null   int64
#  9   koi_fpflag_co      9564 non-null   int64
#  10  koi_fpflag_ec      9564 non-null   int64
#  11  koi_period         9564 non-null   float64
#  12  koi_period_err1    9110 non-null   float64
#  13  koi_period_err2    9110 non-null   float64
#  14  koi_time0bk        9564 non-null   float64
#  15  koi_time0bk_err1   9110 non-null   float64
# ...

# %%
data.mean
# Out:
# <bound method DataFrame.mean of       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0         1  10797460        1080         1035                1
# 1         2  10797460        1081         1036                1
# 2         3  10811496        1082         2294                2
# 3         4  10848459        1083         2294                2
# 4         5  10854555        1084         1867                1
# ...     ...       ...         ...          ...              ...
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# ...

# %%
data.sum
# Out:
# <bound method DataFrame.sum of       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0         1  10797460        1080         1035                1
# 1         2  10797460        1081         1036                1
# 2         3  10811496        1082         2294                2
# 3         4  10848459        1083         2294                2
# 4         5  10854555        1084         1867                1
# ...     ...       ...         ...          ...              ...
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# ...

# %%
data.std
# Out:
# <bound method DataFrame.std of       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0         1  10797460        1080         1035                1
# 1         2  10797460        1081         1036                1
# 2         3  10811496        1082         2294                2
# 3         4  10848459        1083         2294                2
# 4         5  10854555        1084         1867                1
# ...     ...       ...         ...          ...              ...
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# ...

# %%
data1=data['rowid'].apply(lambda x: x%2==0)
data1
# Out:
# 0       False
# 1        True
# 2       False
# 3        True
# 4       False
#         ...
# 9559     True
# 9560    False
# 9561     True
# 9562    False
# 9563     True
# Name: rowid, Length: 9564, dtype: bool

# %%
data.sort_values(by="koi_disposition")
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 2269   2270  11622985        3463         2294                0
# 2264   2265   8240617        3376         2294                0
# 2259   2260  10336951        3280         2294                0
# 2257   2258   7984574        3279         2294                0
# 2256   2257  11768142        3557         2294                0
# ...     ...       ...         ...          ...              ...
# 9555   9556   2697935        4955         2294                2
# 8         9   6721123         107         2294                2
# 9563   9564  10156110        9253         2294                2
# 9553   9554   8565912        9166         2294                2
# 9554   9555   8308347        4861         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 2269                 0      1.000              0              0
# 2264                 0        NaN              0              0
# ...

# %%
data.sort_values(by="koi_disposition", ascending=False)
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 9563   9564  10156110        9253         2294                2
# 9562   9563  10147276        9251         2294                2
# 9560   9561  10090151        9249         2294                2
# 2         3  10811496        1082         2294                2
# 3         4  10848459        1083         2294                2
# ...     ...       ...         ...          ...              ...
# 9526   9527  10011213        9246         2294                0
# 37       38  11138155        1094         2294                0
# 5002   5003   3236705        4391         2294                0
# 5000   5001   5621333        4389         2294                0
# 4999   5000   5621333        4388         2294                0
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 9563                 1      0.000              0              0
# 9562                 1      0.021              0              0
# ...

# %%
data.isnull()
# Out:
#       rowid  kepid  kepoi_name  kepler_name  koi_disposition  \
# 0     False  False       False        False            False
# 1     False  False       False        False            False
# 2     False  False       False        False            False
# 3     False  False       False        False            False
# 4     False  False       False        False            False
# ...     ...    ...         ...          ...              ...
# 9559  False  False       False        False            False
# 9560  False  False       False        False            False
# 9561  False  False       False        False            False
# 9562  False  False       False        False            False
# 9563  False  False       False        False            False
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                False      False          False          False
# 1                False      False          False          False
# ...

# %%
data.isnull().sum()
# Out:
# rowid                   0
# kepid                   0
# kepoi_name              0
# kepler_name             0
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       454
# koi_period_err2       454
# koi_time0bk             0
# koi_time0bk_err1      454
# koi_time0bk_err2      454
# koi_impact            363
# koi_impact_err1       454
# koi_impact_err2       454
# koi_duration            0
# koi_duration_err1     454
# koi_duration_err2     454
# koi_depth             363
# koi_depth_err1        454
# koi_depth_err2        454
# koi_prad              363
# koi_prad_err1         363
# koi_prad_err2         363
# koi_teq               363
# koi_insol             321
# koi_insol_err1        321
# koi_insol_err2        321
# koi_model_snr         363
# koi_tce_plnt_num      346
# ...

# %%
data.notnull()
# Out:
#       rowid  kepid  kepoi_name  kepler_name  koi_disposition  \
# 0      True   True        True         True             True
# 1      True   True        True         True             True
# 2      True   True        True         True             True
# 3      True   True        True         True             True
# 4      True   True        True         True             True
# ...     ...    ...         ...          ...              ...
# 9559   True   True        True         True             True
# 9560   True   True        True         True             True
# 9561   True   True        True         True             True
# 9562   True   True        True         True             True
# 9563   True   True        True         True             True
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                 True       True           True           True
# 1                 True       True           True           True
# ...

# %%
data.notnull()
# Out:
#       rowid  kepid  kepoi_name  kepler_name  koi_disposition  \
# 0      True   True        True         True             True
# 1      True   True        True         True             True
# 2      True   True        True         True             True
# 3      True   True        True         True             True
# 4      True   True        True         True             True
# ...     ...    ...         ...          ...              ...
# 9559   True   True        True         True             True
# 9560   True   True        True         True             True
# 9561   True   True        True         True             True
# 9562   True   True        True         True             True
# 9563   True   True        True         True             True
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                 True       True           True           True
# 1                 True       True           True           True
# ...

# %%
data.fillna(200)
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0         1  10797460        1080         1035                1
# 1         2  10797460        1081         1036                1
# 2         3  10811496        1082         2294                2
# 3         4  10848459        1083         2294                2
# 4         5  10854555        1084         1867                1
# ...     ...       ...         ...          ...              ...
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# 1                    0      0.969              0              0
# ...

# %%
data.drop(3)
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0         1  10797460        1080         1035                1
# 1         2  10797460        1081         1036                1
# 2         3  10811496        1082         2294                2
# 4         5  10854555        1084         1867                1
# 5         6  10872983        1085         1039                1
# ...     ...       ...         ...          ...              ...
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# 1                    0      0.969              0              0
# ...

# %%
data.drop("kepid",axis=1)
# Out:
#       rowid  kepoi_name  kepler_name  koi_disposition  koi_pdisposition  \
# 0         1        1080         1035                1                 0
# 1         2        1081         1036                1                 0
# 2         3        1082         2294                2                 1
# 3         4        1083         2294                2                 1
# 4         5        1084         1867                1                 0
# ...     ...         ...          ...              ...               ...
# 9559   9560        9248         2294                2                 1
# 9560   9561        9249         2294                2                 1
# 9561   9562        9250         2294                0                 0
# 9562   9563        9251         2294                2                 1
# 9563   9564        9253         2294                2                 1
#
#       koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# ...

# %%
data.drop("koi_disposition",axis=1)
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_pdisposition  koi_score  \
# 0         1  10797460        1080         1035                 0      1.000
# 1         2  10797460        1081         1036                 0      0.969
# 2         3  10811496        1082         2294                 1      0.000
# 3         4  10848459        1083         2294                 1      0.000
# 4         5  10854555        1084         1867                 0      1.000
# ...     ...       ...         ...          ...               ...        ...
# 9559   9560  10031643        9248         2294                 1      0.000
# 9560   9561  10090151        9249         2294                 1      0.000
# 9561   9562  10128825        9250         2294                 0      0.497
# 9562   9563  10147276        9251         2294                 1      0.021
# 9563   9564  10156110        9253         2294                 1      0.000
#
# ...

# %%
data.dropna()
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0         1  10797460        1080         1035                1
# 1         2  10797460        1081         1036                1
# 2         3  10811496        1082         2294                2
# 3         4  10848459        1083         2294                2
# 4         5  10854555        1084         1867                1
# ...     ...       ...         ...          ...              ...
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# 1                    0      0.969              0              0
# ...

# %%
data.iloc[0]
# Out:
# rowid                1.000000e+00
# kepid                1.079746e+07
# kepoi_name           1.080000e+03
# kepler_name          1.035000e+03
# koi_disposition      1.000000e+00
# koi_pdisposition     0.000000e+00
# koi_score            1.000000e+00
# koi_fpflag_nt        0.000000e+00
# koi_fpflag_ss        0.000000e+00
# koi_fpflag_co        0.000000e+00
# koi_fpflag_ec        0.000000e+00
# koi_period           9.488036e+00
# koi_period_err1      2.780000e-05
# koi_period_err2     -2.780000e-05
# koi_time0bk          1.705387e+02
# koi_time0bk_err1     2.160000e-03
# koi_time0bk_err2    -2.160000e-03
# koi_impact           1.460000e-01
# koi_impact_err1      3.180000e-01
# koi_impact_err2     -1.460000e-01
# koi_duration         2.957500e+00
# koi_duration_err1    8.190000e-02
# koi_duration_err2   -8.190000e-02
# koi_depth            6.160000e+02
# koi_depth_err1       1.950000e+01
# koi_depth_err2      -1.950000e+01
# koi_prad             2.260000e+00
# ...

# %%
data.iloc[2:8]
# Out:
#    rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 2      3  10811496        1082         2294                2
# 3      4  10848459        1083         2294                2
# 4      5  10854555        1084         1867                1
# 5      6  10872983        1085         1039                1
# 6      7  10872983        1086         1038                1
# 7      8  10872983        1087         1037                1
#
#    koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 2                 1      0.000              0              1              0
# 3                 1      0.000              0              1              0
# 4                 0      1.000              0              0              0
# 5                 0      1.000              0              0              0
# 6                 0      1.000              0              0              0
# 7                 0      0.992              0              0              0
#
# ...

# %%
data.iloc[0:5,0:3]
# Out:
#    rowid     kepid  kepoi_name
# 0      1  10797460        1080
# 1      2  10797460        1081
# 2      3  10811496        1082
# 3      4  10848459        1083
# 4      5  10854555        1084

# %%
data.iloc[2:15]
# Out:
#     rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 2       3  10811496        1082         2294                2
# 3       4  10848459        1083         2294                2
# 4       5  10854555        1084         1867                1
# 5       6  10872983        1085         1039                1
# 6       7  10872983        1086         1038                1
# 7       8  10872983        1087         1037                1
# 8       9   6721123         107         2294                2
# 9      10  10910878        1088         1041                1
# 10     11  11446443           0            0                1
# 11     12  10666592           1          953                1
# 12     13   6922244          10         2030                1
# 13     14  10984090         105         1603                1
# 14     15  10419211        1064         2294                2
#
#     koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# ...

# %%
df=data.loc[6:,"koi_score"]
df
# Out:
# 6       1.000
# 7       0.992
# 8       0.000
# 9       1.000
# 10      0.811
#         ...
# 9559    0.000
# 9560    0.000
# 9561    0.497
# 9562    0.021
# 9563    0.000
# Name: koi_score, Length: 9558, dtype: float64

# %%
df.cum().sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6912\675836338.py in ?()
# ----> 1 df.cum().sum()
#
# ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'cum'

# %%
data.isnull()

# %%
data.fillna(200)
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0         1  10797460        1080         1035                1
# 1         2  10797460        1081         1036                1
# 2         3  10811496        1082         2294                2
# 3         4  10848459        1083         2294                2
# 4         5  10854555        1084         1867                1
# ...     ...       ...         ...          ...              ...
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# 1                    0      0.969              0              0
# ...

# %%
data.isnull().sum()
# Out:
# rowid                   0
# kepid                   0
# kepoi_name              0
# kepler_name             0
# koi_disposition         0
# koi_pdisposition        0
# koi_score            1510
# koi_fpflag_nt           0
# koi_fpflag_ss           0
# koi_fpflag_co           0
# koi_fpflag_ec           0
# koi_period              0
# koi_period_err1       454
# koi_period_err2       454
# koi_time0bk             0
# koi_time0bk_err1      454
# koi_time0bk_err2      454
# koi_impact            363
# koi_impact_err1       454
# koi_impact_err2       454
# koi_duration            0
# koi_duration_err1     454
# koi_duration_err2     454
# koi_depth             363
# koi_depth_err1        454
# koi_depth_err2        454
# koi_prad              363
# koi_prad_err1         363
# koi_prad_err2         363
# koi_teq               363
# koi_insol             321
# koi_insol_err1        321
# koi_insol_err2        321
# koi_model_snr         363
# koi_tce_plnt_num      346
# ...

# %%
data5=data.fillna(200)
data5
# Out:
#       rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 0         1  10797460        1080         1035                1
# 1         2  10797460        1081         1036                1
# 2         3  10811496        1082         2294                2
# 3         4  10848459        1083         2294                2
# 4         5  10854555        1084         1867                1
# ...     ...       ...         ...          ...              ...
# 9559   9560  10031643        9248         2294                2
# 9560   9561  10090151        9249         2294                2
# 9561   9562  10128825        9250         2294                0
# 9562   9563  10147276        9251         2294                2
# 9563   9564  10156110        9253         2294                2
#
#       koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  \
# 0                    0      1.000              0              0
# 1                    0      0.969              0              0
# ...

# %%
data4=data["kepoi_name"].head()	
data4
# Out:
# 0    1080
# 1    1081
# 2    1082
# 3    1083
# 4    1084
# Name: kepoi_name, dtype: int64

# %%
data5=data["kepoi_name"].head(120)
data5
# Out:
# 0      1080
# 1      1081
# 2      1082
# 3      1083
# 4      1084
#        ...
# 115    1168
# 116    1169
# 117    1170
# 118      11
# 119     115
# Name: kepoi_name, Length: 120, dtype: int64

# %%
x1=data.iloc[2:7]
x1
# Out:
#    rowid     kepid  kepoi_name  kepler_name  koi_disposition  \
# 2      3  10811496        1082         2294                2
# 3      4  10848459        1083         2294                2
# 4      5  10854555        1084         1867                1
# 5      6  10872983        1085         1039                1
# 6      7  10872983        1086         1038                1
#
#    koi_pdisposition  koi_score  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 2                 1        0.0              0              1              0
# 3                 1        0.0              0              1              0
# 4                 0        1.0              0              0              0
# 5                 0        1.0              0              0              0
# 6                 0        1.0              0              0              0
#
#    ...  koi_steff_err2  koi_slogg  koi_slogg_err1  koi_slogg_err2  koi_srad  \
# ...

# %%
x=data['kepid']
x
# Out:
# 0       10797460
# 1       10797460
# 2       10811496
# 3       10848459
# 4       10854555
#           ...
# 9559    10031643
# 9560    10090151
# 9561    10128825
# 9562    10147276
# 9563    10156110
# Name: kepid, Length: 9564, dtype: int64

# %%
y=data['koi_kepmag']
y
# Out:
# 0       15.347
# 1       15.347
# 2       15.436
# 3       15.597
# 4       15.509
#          ...
# 9559    14.478
# 9560    14.082
# 9561    14.757
# 9562    15.385
# 9563    14.826
# Name: koi_kepmag, Length: 9564, dtype: float64

# %%
plt.scatter(x,y , marker="*", color="red",label="data")
plt.xlabel("kapid")
plt.ylabel("koi_kepmag")
plt.title("INFORMATION ON KAPID NETWORK")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(x,y , marker="*", color="red",label="data")
plt.xlabel("kapid")
plt.ylabel("koi_kepmag")
plt.title("INFORMATION ON KAPID NETWORK")
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.bar(x,y, color="green",label="data")
plt.xlabel("kepid")
plt.ylabel("koi_kepmag")
plt.title("INFORMATION ON KAPID NETWORK")
plt.legend()
plt.grid()
plt.show()

# %%
data["kepid"]=pd. to_numeric(data["kepid"],errors="coerce")
data["koi_kepmag"]=pd. to_numeric(data["koi_kepmag"],errors="coerce")

# %%
plt.imshow(data, cmap = 'plasma', interpolation = 'nearest')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
data.koi_pdisposition.unique()

# %%
data["kepoi_name"].value_counts()
#data["Car_Model"].value_counts()
# Out:
# kepoi_name
# K00752.01    1
# K00752.02    1
# K00753.01    1
# K00754.01    1
# K00755.01    1
#             ..
# K07984.01    1
# K07985.01    1
# K07986.01    1
# K07987.01    1
# K07989.01    1
# Name: count, Length: 9564, dtype: int64

# %%
sns.displot(data["kepoi_name"])

# %%
sns.distplot(data["kepoi_name"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_18280\900968675.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["kepoi_name"])
# <Axes: xlabel='kepoi_name', ylabel='Density'>

# %%
sns.boxplot(x=data["kepoi_name"])
# Out:
# <Axes: xlabel='kepoi_name'>

# %%
sns.scatterplot(x=data["kepoi_name"],y=data["koi_kepmag"])
plt.show()

# %%
sns.jointplot(x="koi_kepmag",y="kepoi_name" ,data=data)

# %%
X = data.drop('koi_score', axis = 1)

# %%
X
# Out:
#       rowid     kepid kepoi_name   kepler_name koi_disposition  \
# 0         1  10797460  K00752.01  Kepler-227 b       CONFIRMED
# 1         2  10797460  K00752.02  Kepler-227 c       CONFIRMED
# 2         3  10811496  K00753.01           NaN  FALSE POSITIVE
# 3         4  10848459  K00754.01           NaN  FALSE POSITIVE
# 4         5  10854555  K00755.01  Kepler-664 b       CONFIRMED
# ...     ...       ...        ...           ...             ...
# 9559   9560  10031643  K07984.01           NaN  FALSE POSITIVE
# 9560   9561  10090151  K07985.01           NaN  FALSE POSITIVE
# 9561   9562  10128825  K07986.01           NaN       CANDIDATE
# 9562   9563  10147276  K07987.01           NaN  FALSE POSITIVE
# 9563   9564  10156110  K07989.01           NaN  FALSE POSITIVE
#
#      koi_pdisposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  \
# 0           CANDIDATE              0              0              0
# 1           CANDIDATE              0              0              0
# ...

# %%
Y = data['koi_score']
Y
# Out:
# 0       1.000
# 1       0.969
# 2       0.000
# 3       0.000
# 4       1.000
#         ...
# 9559    0.000
# 9560    0.000
# 9561    0.497
# 9562    0.021
# 9563    0.000
# Name: koi_score, Length: 9564, dtype: float64

# %%
x_train,x_test,y_train,y_test= train_test_split(x,y, test_size=0.2, random_state=47)

# %%
x_train
# Out:
# 3027     2576197
# 6227     5094412
# 3084    11913012
# 7613     2442084
# 6797    11654039
#           ...
# 2896    11442793
# 8883     5460835
# 6728     7377343
# 1926    11358389
# 5255    10268903
# Name: kepid, Length: 7651, dtype: int64

# %%
y_train
# Out:
# 3027    0.000
# 6227    0.000
# 3084    0.000
# 7613    0.000
# 6797      NaN
#         ...
# 2896    0.880
# 8883    0.000
# 6728    1.000
# 1926    0.995
# 5255    0.000
# Name: koi_score, Length: 7651, dtype: float64

# %%
model=Logistic_regrresion.pkl
if os.path.exists(model):
    logistic_regression=joblib.load(model)
    predict=logistic_regression.predict(x_test)
    calculatemetrics("Logistic Regfeesion",precict,y_test)
else:
    logistic_regression=LogisticRegression()
    logistic_regression.fit(x_train,y_train)
    predict = logistic_regression.predict(x_test)
    joblib.dump(logistic_regression, model)
    print("Logistic Regression trained and model weights saved")
    calculateMetrics("Logistic Regresiion",predict,y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model=Logistic_regrresion.pkl
#       2 if os.path.exists(model):
#       3     logistic_regression=joblib.load(model)
#
# NameError: name 'Logistic_regrresion' is not defined

# %%
model = 'logistic_regression.pkl'
if os.path.exists(model):
    logistic_regression = joblib.load(model)
    predict = logistic_regression.predict(x_test)
    calculateMetrics("Logistic Regression", predict, y_test)
else:
    logistic_regression = LogisticRegression()
    logistic_regression.fit(x_train, y_train)
    predict = logistic_regression.predict(x_test)
    joblib.dump(logistic_regression, model)
    print("Logistic Regression trained and model weights saved.")
    calculateMetrics("Logistic Regression", predict, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 model = 'logistic_regression.pkl'
# ----> 2 if os.path.exists(model):
#       3     logistic_regression = joblib.load(model)
#       4     predict = logistic_regression.predict(x_test)
#
# NameError: name 'os' is not defined

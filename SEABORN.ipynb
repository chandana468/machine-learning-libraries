# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv("car_sales.csv")
data
# Out:
#         Car_Model  Year Month Region  Units_Sold  Price_per_Unit    Revenue  \
# 0      Kia Seltos  2020   Sep   East         214         1334878  285663892
# 1      Kia Seltos  2018   Jun  South         289         1179605  340905845
# 2      Honda City  2022   Sep  North         408         1287488  525295104
# 3    Maruti Swift  2019   Feb  North         300          602865  180859500
# 4      Honda City  2020   Sep  North          87          510448   44408976
# ..            ...   ...   ...    ...         ...             ...        ...
# 229   Hyundai i20  2022   Aug  South         148         1442407  213476236
# 230    Honda City  2020   Jan   East         266          975584  259505344
# 231  Maruti Swift  2018   Dec   East         204          689062  140568648
# 232   Hyundai i20  2018   Jul   West         357          780020  278467140
# 233    Tata Nexon  2020   May  North         374         1183262  442539988
#
#        Dealer
# 0    Dealer D
# 1    Dealer C
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 234 entries, 0 to 233
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Car_Model       234 non-null    object
#  1   Year            234 non-null    int64
#  2   Month           234 non-null    object
#  3   Region          234 non-null    object
#  4   Units_Sold      234 non-null    int64
#  5   Price_per_Unit  234 non-null    int64
#  6   Revenue         234 non-null    int64
#  7   Dealer          234 non-null    object
# dtypes: int64(4), object(4)
# memory usage: 14.8+ KB

# %%
data.describe()
# Out:
#               Year  Units_Sold  Price_per_Unit       Revenue
# count   234.000000  234.000000    2.340000e+02  2.340000e+02
# mean   2020.914530  258.393162    9.845656e+05  2.535589e+08
# std       1.970045  141.255921    2.958763e+05  1.621072e+08
# min    2018.000000   17.000000    5.003590e+05  1.832241e+07
# 25%    2019.000000  140.000000    7.328590e+05  1.232755e+08
# 50%    2021.000000  265.500000    9.753205e+05  2.359470e+08
# 75%    2023.000000  379.500000    1.217988e+06  3.540403e+08
# max    2024.000000  499.000000    1.492059e+06  7.324161e+08

# %%
data.isnull()
# Out:
#      Car_Model   Year  Month  Region  Units_Sold  Price_per_Unit  Revenue  \
# 0        False  False  False   False       False           False    False
# 1        False  False  False   False       False           False    False
# 2        False  False  False   False       False           False    False
# 3        False  False  False   False       False           False    False
# 4        False  False  False   False       False           False    False
# ..         ...    ...    ...     ...         ...             ...      ...
# 229      False  False  False   False       False           False    False
# 230      False  False  False   False       False           False    False
# 231      False  False  False   False       False           False    False
# 232      False  False  False   False       False           False    False
# 233      False  False  False   False       False           False    False
#
#      Dealer
# 0     False
# 1     False
# 2     False
# 3     False
# ...

# %%
data.isnull().sum()
# Out:
# Car_Model         0
# Year              0
# Month             0
# Region            0
# Units_Sold        0
# Price_per_Unit    0
# Revenue           0
# Dealer            0
# dtype: int64

# %%
data.sort_values(by="Car_Model")
# Out:
#       Car_Model  Year Month Region  Units_Sold  Price_per_Unit    Revenue  \
# 171  Honda City  2023   May  North         299          916137  273924963
# 97   Honda City  2024   Feb   East          30          645387   19361610
# 149  Honda City  2021   Sep  South          52          920376   47859552
# 95   Honda City  2020   Jul   West         307          899166  276043962
# 121  Honda City  2024   Nov  South         455         1315619  598606645
# ..          ...   ...   ...    ...         ...             ...        ...
# 33   Tata Nexon  2022   Oct   West         493          813912  401258616
# 143  Tata Nexon  2019   Oct  South         264          595276  157152864
# 142  Tata Nexon  2023   Nov   East          53          627760   33271280
# 102  Tata Nexon  2024   Sep   West         184          996116  183285344
# 233  Tata Nexon  2020   May  North         374         1183262  442539988
#
#        Dealer
# 171  Dealer A
# 97   Dealer D
# 149  Dealer C
# 95   Dealer A
# ...

# %%
data.Dealer.unique()
# Out:
# array(['Dealer D', 'Dealer C', 'Dealer B', 'Dealer A'], dtype=object)

# %%
data["Car_Model"].value_counts()
# Out:
# Car_Model
# Maruti Swift    53
# Kia Seltos      50
# Honda City      50
# Hyundai i20     44
# Tata Nexon      37
# Name: count, dtype: int64

# %%
sns.displot(data["Car_Model"])

# %%
sns.distplot(data["Units_Sold"])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_2212\724761505.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Units_Sold"])
# <Axes: xlabel='Units_Sold', ylabel='Density'>

# %%
sns.displot(data['Car_Model'],bins=10,kde=True)
plt.title('Histogram of Car_Model')
plt.show()

# %%
sns.boxplot(x=data['Car_Model'])
# Out:
# <Axes: xlabel='Car_Model'>

# %%
sns.scatterplot(x=data['Car_Model'],y=data['Year'])
plt.show()

# %%
sns.scatterplot(x=data['Car_Model'],y=data['Year'],data=data)
plt.show()

# %%
sns.relplot(x='Car_Model',y="Year",data = data,hue='Dealer')

# %%
sns.jointplot(x='Car_Model',y='Year',data=data)

# %%
sns.violinplot(x='Car_Model',y='Year',data=data)
# Out:
# <Axes: xlabel='Car_Model', ylabel='Year'>

# %%
sns.relplot(x="Car_Model",y='Year',kind='line',data=data)
plt.show()
